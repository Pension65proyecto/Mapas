# %%
import pandas as pd
import os

p65 = pd.read_excel(os.path.join("Vester.xlsx"),
                          index_col=0)

# %%
p65.head()
# Out:
#                                                 Direccion Ejecutiva MIDIS  \
# Direccion Ejecutiva MIDIS                                               1
# Direccion General de Gestion de Usuarios MIDIS                          1
# RENIEC                                                                  1
# ESSALUD                                                                 1
# MINSA SIS Centro de salud                                               1
#
#                                                 Direccion General de Gestion de Usuarios MIDIS  \
# Direccion Ejecutiva MIDIS                                                                    1
# Direccion General de Gestion de Usuarios MIDIS                                               1
# RENIEC                                                                                       1
# ESSALUD                                                                                      1
# MINSA SIS Centro de salud                                                                    0
#
#                                                 RENIEC  ESSALUD  \
# Direccion Ejecutiva MIDIS                            1        1
# Direccion General de Gestion de Usuarios MIDIS       1        1
# RENIEC                                               0        0
# ESSALUD                                              0        0
# MINSA SIS Centro de salud                            0        0
#
#                                                 MINSA SIS Centro de salud  \
# Direccion Ejecutiva MIDIS                                               1
# Direccion General de Gestion de Usuarios MIDIS                          0
# RENIEC                                                                  0
# ESSALUD                                                                 0
# MINSA SIS Centro de salud                                               0
#
#                                                 ONP  SBS  Sistema bancario  \
# Direccion Ejecutiva MIDIS                         1    1                 1
# Direccion General de Gestion de Usuarios MIDIS    1    1                 1
# RENIEC                                            0    0                 0
# ESSALUD                                           0    0                 0
# MINSA SIS Centro de salud                         0    0                 0
#
#                                                 Gobierno local  \
# Direccion Ejecutiva MIDIS                                    1
# Direccion General de Gestion de Usuarios MIDIS               1
# RENIEC                                                       0
# ESSALUD                                                      0
# MINSA SIS Centro de salud                                    0
#
#                                                 Gobierno regional  \
# Direccion Ejecutiva MIDIS                                       1
# Direccion General de Gestion de Usuarios MIDIS                  0
# RENIEC                                                          0
# ESSALUD                                                         0
# MINSA SIS Centro de salud                                       0
#
#                                                 Gobierno nacional  \
# Direccion Ejecutiva MIDIS                                       1
# Direccion General de Gestion de Usuarios MIDIS                  0
# RENIEC                                                          0
# ESSALUD                                                         0
# MINSA SIS Centro de salud                                       0
#
#                                                 Otras instituciones  \
# Direccion Ejecutiva MIDIS                                         1
# Direccion General de Gestion de Usuarios MIDIS                    1
# RENIEC                                                            0
# ESSALUD                                                           0
# MINSA SIS Centro de salud                                         0
#
#                                                 Programas sociales
# Direccion Ejecutiva MIDIS                                        0
# Direccion General de Gestion de Usuarios MIDIS                   1
# RENIEC                                                           0
# ESSALUD                                                          0
# MINSA SIS Centro de salud                                        0

# %%
import networkx as nx
mapa = nx.from_pandas_adjacency(p65)

# %%
#nodes
len(mapa)
# Out:
# 13

# %%
#edges
mapa.size()
# Out:
# 22

# %%
# plot
nx.draw_random(mapa,
                node_color='yellow',
                edge_color='lightblue',
                with_labels=True,
                font_size=8)

# %%
mapa.remove_edges_from(nx.selfloop_edges(mapa))

# %%
# re plot
nx.draw_random(mapa,
                node_color='yellow',
                edge_color='lightblue',
                with_labels=True,
                font_size=8)

# %%
nx.draw_circular(mapa,
        with_labels=True)

# %%
nx.write_graphml(mapa, "Vesterp65.graphml",encoding='utf-8')
