# %%
import os, geopandas as gpd
PeruDepartamentos=gpd.read_file(os.path.join("PeruMaps.gpkg"), layer = "Departamentos")

# %%
PeruDepartamentos.plot(facecolor="white", edgecolor = "black")
# Out:
# <Axes: >

# %%
import pandas as pd
DatosDepartamentos=pd.read_excel(os.path.join("Datos_por_zona", "DatosRegionales", "DatosRegionales.xlsx"))

# %%
DatosDepartamentos.head()
# Out:
#    Ubigeo Departamento      Capital  Transferencia2023  Transferencia2022  \
# 0       1     Amazonas  Chachapoyas           14922000           21421250
# 1       2       Áncash       Huaraz           38474000           54336250
# 2       3     Apurímac      Abancay           29541000           41769000
# 3       4     Arequipa     Arequipa           10547000           14913750
# 4       5     Ayacucho     Ayacucho           37669000           53259250
#
#    Transferencia2021  Transferencia2020  Transferencia2019  Transferencia2018  \
# 0           26711750           23282750           19145500           18791000
# 1           69794500           61096250           51928000           51692750
# 2           53457500           46832500           39743500           39522750
# 3           19065250           16707000           14020000           13881750
# 4           68288250           59865500           50904000           50739250
#
#    Transferencia2017  Transferencia2016  Transferencia2015  Transferencia2014  \
# 0           18377250           18135500           16827500        14832003.77
# 1           50029500           47022500           44815000        41715160.28
# 2           39474500           39284250           38134000        36471231.08
# 3           13308000           12798500           11930750        10023709.11
# 4           49619250           48314750           46089750        42454612.59
#
#    Transferencia2013
# 0        10307162.27
# 1        28493264.69
# 2        29721688.82
# 3         3716898.67
# 4        33460838.38

# %%
PeruDepartamentos.head()
# Out:
#    OBJECTID CCDD   NOMBDEP                 FUENTE  FUENTE_1  POB_PROYEC  \
# 0       1.0   01  AMAZONAS  INEI - CPV RESULTADOS       NaN    426806.0
# 1       2.0   02    ANCASH  INEI - CPV RESULTADOS       NaN   1180638.0
# 2       3.0   03  APURIMAC  INEI - CPV RESULTADOS       NaN    430736.0
# 3       4.0   04  AREQUIPA  INEI - CPV RESULTADOS       NaN   1497438.0
# 4       5.0   05  AYACUCHO  INEI - CPV RESULTADOS       NaN    668213.0
#
#     POBTOTAL  POB_EDAD_T  POB_EDAD_1  POB_EDAD_E  ...  IND_121951  \
# 0   417365.0    289648.0        69.4    239212.0  ...      2139.0
# 1  1139115.0    850842.0        74.7    701614.0  ...      9366.0
# 2   424259.0    310196.0        73.1    252356.0  ...      3723.0
# 3  1460433.0   1135965.0        77.8    970511.0  ...     10670.0
# 4   650940.0    478429.0        73.5    390780.0  ...      4699.0
#
#      IND_122042    IND_122047   IND_516462  IND_516484  Shape_Le_1  \
# 0  3.184694e+05  3.745422e+05   5094318.10     34164.0    0.022988
# 1  2.252303e+06  1.363318e+06  34431748.77     74385.0    0.000000
# 2  7.025553e+05  6.626253e+05   8673503.09     48594.0    0.000000
# 3  2.094167e+06  1.296536e+06  64872968.90     48033.0    0.000000
# 4  9.729801e+05  9.490687e+05  14610956.27     58941.0    0.000000
#
#    Shape_Ar_1  Shape_Le_2  Shape_Ar_2  \
# 0    0.000013   12.894071    3.203362
# 1    0.000000   11.640227    2.954639
# 2    0.000000    7.730082    1.765933
# 3    0.000000   17.391102    5.330046
# 4    0.000000   17.132543    3.643617
#
#                                             geometry
# 0  POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 1  POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...
# 2  POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4  POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
#
# [5 rows x 80 columns]

# %%
#Remover tiles
DatosDepartamentos['Departamento']=DatosDepartamentos['Departamento'].str.normalize('NFKD').\
                        str.encode('ascii', errors='ignore').str.decode('utf-8').str.upper()

# %%
DatosDepartamentos.head()
# Out:
#    Ubigeo Departamento      Capital  Transferencia2023  Transferencia2022  \
# 0       1     AMAZONAS  Chachapoyas           14922000           21421250
# 1       2       ANCASH       Huaraz           38474000           54336250
# 2       3     APURIMAC      Abancay           29541000           41769000
# 3       4     AREQUIPA     Arequipa           10547000           14913750
# 4       5     AYACUCHO     Ayacucho           37669000           53259250
#
#    Transferencia2021  Transferencia2020  Transferencia2019  Transferencia2018  \
# 0           26711750           23282750           19145500           18791000
# 1           69794500           61096250           51928000           51692750
# 2           53457500           46832500           39743500           39522750
# 3           19065250           16707000           14020000           13881750
# 4           68288250           59865500           50904000           50739250
#
#    Transferencia2017  Transferencia2016  Transferencia2015  Transferencia2014  \
# 0           18377250           18135500           16827500        14832003.77
# 1           50029500           47022500           44815000        41715160.28
# 2           39474500           39284250           38134000        36471231.08
# 3           13308000           12798500           11930750        10023709.11
# 4           49619250           48314750           46089750        42454612.59
#
#    Transferencia2013
# 0        10307162.27
# 1        28493264.69
# 2        29721688.82
# 3         3716898.67
# 4        33460838.38

# %%
PeruDepartamentos.head()
# Out:
#    OBJECTID CCDD   NOMBDEP                 FUENTE  FUENTE_1  POB_PROYEC  \
# 0       1.0   01  AMAZONAS  INEI - CPV RESULTADOS       NaN    426806.0
# 1       2.0   02    ANCASH  INEI - CPV RESULTADOS       NaN   1180638.0
# 2       3.0   03  APURIMAC  INEI - CPV RESULTADOS       NaN    430736.0
# 3       4.0   04  AREQUIPA  INEI - CPV RESULTADOS       NaN   1497438.0
# 4       5.0   05  AYACUCHO  INEI - CPV RESULTADOS       NaN    668213.0
#
#     POBTOTAL  POB_EDAD_T  POB_EDAD_1  POB_EDAD_E  ...  IND_121951  \
# 0   417365.0    289648.0        69.4    239212.0  ...      2139.0
# 1  1139115.0    850842.0        74.7    701614.0  ...      9366.0
# 2   424259.0    310196.0        73.1    252356.0  ...      3723.0
# 3  1460433.0   1135965.0        77.8    970511.0  ...     10670.0
# 4   650940.0    478429.0        73.5    390780.0  ...      4699.0
#
#      IND_122042    IND_122047   IND_516462  IND_516484  Shape_Le_1  \
# 0  3.184694e+05  3.745422e+05   5094318.10     34164.0    0.022988
# 1  2.252303e+06  1.363318e+06  34431748.77     74385.0    0.000000
# 2  7.025553e+05  6.626253e+05   8673503.09     48594.0    0.000000
# 3  2.094167e+06  1.296536e+06  64872968.90     48033.0    0.000000
# 4  9.729801e+05  9.490687e+05  14610956.27     58941.0    0.000000
#
#    Shape_Ar_1  Shape_Le_2  Shape_Ar_2  \
# 0    0.000013   12.894071    3.203362
# 1    0.000000   11.640227    2.954639
# 2    0.000000    7.730082    1.765933
# 3    0.000000   17.391102    5.330046
# 4    0.000000   17.132543    3.643617
#
#                                             geometry
# 0  POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 1  POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...
# 2  POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4  POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
#
# [5 rows x 80 columns]

# %%
DatosDepartamentos.iloc[:,2:].describe().loc[['min','max']].T
# Out:
#                           min           max
# Transferencia2023  1757000.00  7.004200e+07
# Transferencia2022  2538250.00  9.868275e+07
# Transferencia2021  2582500.00  1.265355e+08
# Transferencia2020  2044000.00  1.109562e+08
# Transferencia2019  1629750.00  9.329250e+07
# Transferencia2018  1486750.00  9.253300e+07
# Transferencia2017  1372000.00  8.741175e+07
# Transferencia2016  1198000.00  8.358800e+07
# Transferencia2015   970750.00  8.239000e+07
# Transferencia2014   532107.03  8.068887e+07
# Transferencia2013   144505.78  6.492335e+07

# %%
import matplotlib.pyplot as plt

PeruDepartamentos.iloc[:,2:].plot(kind='box', rot=90)
# Out:
# <Axes: >

# %%
columnsToScale=['Transferencia2023'] # you can add more columns

from sklearn import preprocessing

# prepare the process
minmaxSc = preprocessing.MinMaxScaler(feature_range=(0, 10))# default is 0,1

# apply process
minmaxResult = minmaxSc.fit_transform(DatosDepartamentos[columnsToScale])

# result
minmaxResult
# Out:
# array([[ 1.92794904],
#        [ 5.37702277],
#        [ 4.06882917],
#        [ 1.28725196],
#        [ 5.25913451],
#        [10.        ],
#        [ 0.46056967],
#        [ 5.93219594],
#        [ 3.39488907],
#        [ 4.24104855],
#        [ 0.79124259],
#        [ 3.90114959],
#        [ 3.81064655],
#        [ 2.7552171 ],
#        [ 5.58922164],
#        [ 4.21908179],
#        [ 0.        ],
#        [ 0.26228308],
#        [ 0.81584535],
#        [ 6.88892143],
#        [ 8.80061507],
#        [ 3.22428059],
#        [ 0.15757487],
#        [ 0.46188768],
#        [ 1.89690269]])

# %%
# new values to new column
DatosDepartamentos['Trans2023_minMax']=minmaxResult

# %%
DatosDepartamentos.head()
# Out:
#    Ubigeo Departamento      Capital  Transferencia2023  Transferencia2022  \
# 0       1     AMAZONAS  Chachapoyas           14922000           21421250
# 1       2       ANCASH       Huaraz           38474000           54336250
# 2       3     APURIMAC      Abancay           29541000           41769000
# 3       4     AREQUIPA     Arequipa           10547000           14913750
# 4       5     AYACUCHO     Ayacucho           37669000           53259250
#
#    Transferencia2021  Transferencia2020  Transferencia2019  Transferencia2018  \
# 0           26711750           23282750           19145500           18791000
# 1           69794500           61096250           51928000           51692750
# 2           53457500           46832500           39743500           39522750
# 3           19065250           16707000           14020000           13881750
# 4           68288250           59865500           50904000           50739250
#
#    Transferencia2017  Transferencia2016  Transferencia2015  Transferencia2014  \
# 0           18377250           18135500           16827500        14832003.77
# 1           50029500           47022500           44815000        41715160.28
# 2           39474500           39284250           38134000        36471231.08
# 3           13308000           12798500           11930750        10023709.11
# 4           49619250           48314750           46089750        42454612.59
#
#    Transferencia2013  Trans2023_minMax
# 0        10307162.27          1.927949
# 1        28493264.69          5.377023
# 2        29721688.82          4.068829
# 3         3716898.67          1.287252
# 4        33460838.38          5.259135

# %%
# prepare the process
stdSc = preprocessing.StandardScaler()

# apply process
stdScResult = stdSc.fit_transform(DatosDepartamentos.iloc[:,3:-1])

# result
stdScResult
# Out:
# array([[-5.59974836e-01, -5.49934601e-01, -5.39808195e-01,
#         -5.39748070e-01, -5.52742353e-01, -5.57329816e-01,
#         -5.48727744e-01, -5.25513911e-01, -5.30149547e-01,
#         -4.92087364e-01, -3.86751065e-01],
#        [ 7.33657246e-01,  7.32908616e-01,  7.55662614e-01,
#          7.53367712e-01,  7.75761628e-01,  7.84729952e-01,
#          7.88568381e-01,  7.47598864e-01,  7.57527978e-01,
#          7.91482797e-01,  7.14210647e-01],
#        [ 2.42997626e-01,  2.43107266e-01,  2.64419446e-01,
#          2.65587416e-01,  2.81987305e-01,  2.88316619e-01,
#          3.42623445e-01,  4.06557394e-01,  4.50141697e-01,
#          5.41104793e-01,  7.88577760e-01],
#        [-8.00278859e-01, -8.03560675e-01, -7.69733572e-01,
#         -7.64620301e-01, -7.60452173e-01, -7.57577734e-01,
#         -7.62901725e-01, -7.60727082e-01, -7.55444229e-01,
#         -7.21665448e-01, -7.85716590e-01],
#        [ 6.89441306e-01,  6.90933159e-01,  7.10370638e-01,
#          7.11279510e-01,  7.34264242e-01,  7.45836763e-01,
#          7.71235466e-01,  8.04551125e-01,  8.16177980e-01,
#          8.26788878e-01,  1.01494075e+00],
#        [ 2.46758123e+00,  2.46128798e+00,  2.46182829e+00,
#          2.45844005e+00,  2.45204937e+00,  2.45060051e+00,
#          2.36795494e+00,  2.26893712e+00,  2.12574430e+00,
#          1.98832824e+00,  1.43296157e+00],
#        [-1.11033971e+00, -1.11444018e+00, -1.08643161e+00,
#         -1.08075631e+00, -1.07528928e+00, -1.07052820e+00,
#         -1.07797841e+00, -1.07769413e+00, -1.06712085e+00,
#         -1.08515264e+00, -9.70669500e-01],
#        [ 9.41884116e-01,  9.42240255e-01,  9.47211968e-01,
#          9.48419986e-01,  9.11185351e-01,  8.93169956e-01,
#          9.37878604e-01,  1.01362950e+00,  1.03173025e+00,
#          1.08140608e+00,  1.20780940e+00],
#        [-9.77474377e-03, -1.05480385e-02,  1.61592752e-02,
#          1.79483999e-02,  2.61948201e-02,  3.14522919e-02,
#          4.63901032e-02,  7.77569702e-02,  1.40178910e-01,
#          2.45285136e-01,  4.10332410e-01],
#        [ 3.07591347e-01,  3.19497140e-01,  3.53785590e-01,
#          3.55124232e-01,  3.46320412e-01,  3.43015903e-01,
#          4.03315051e-01,  4.75232853e-01,  5.62104654e-01,
#          7.15570768e-01,  9.68974956e-01],
#        [-9.86315368e-01, -9.90111763e-01, -9.58283507e-01,
#         -9.52645050e-01, -9.41648647e-01, -9.28548686e-01,
#         -9.26175454e-01, -9.23783093e-01, -9.27391450e-01,
#         -8.86944329e-01, -7.84097117e-01],
#        [ 1.80106630e-01,  1.94886158e-01,  1.52907217e-01,
#          1.42631387e-01,  1.23271958e-01,  1.11941003e-01,
#          1.52838068e-01,  2.02899897e-01,  2.01877010e-01,
#          1.57931379e-01,  1.33720349e-01],
#        [ 1.46161970e-01,  1.43673763e-01,  1.70678210e-01,
#          1.72588133e-01,  1.86916144e-01,  1.94652764e-01,
#          2.15895654e-01,  2.07769872e-01,  2.21591876e-01,
#          2.75628984e-01,  5.42735688e-01],
#        [-2.49694281e-01, -2.51341783e-01, -2.19343969e-01,
#         -2.11754185e-01, -2.05343577e-01, -1.99377868e-01,
#         -2.01889898e-01, -2.26385075e-01, -2.36025367e-01,
#         -3.97274526e-01, -7.63573701e-01],
#        [ 8.13245939e-01,  8.02429247e-01,  8.27212661e-01,
#          8.35022074e-01,  7.89955437e-01,  7.69760051e-01,
#          6.25083404e-01,  5.07074996e-01,  3.31035839e-01,
#          8.62712069e-02, -2.82802081e-01],
#        [ 2.99352352e-01,  2.98869926e-01,  3.28552885e-02,
#          1.05498359e-03, -2.58791319e-03, -2.60003112e-02,
#         -9.92232764e-02, -1.74192608e-01, -2.22360687e-01,
#         -4.01545783e-01, -5.59202248e-01],
#        [-1.28308397e+00, -1.28588868e+00, -1.26535935e+00,
#         -1.26605383e+00, -1.26256447e+00, -1.26316880e+00,
#         -1.26719341e+00, -1.27198629e+00, -1.25970312e+00,
#         -1.17485394e+00, -1.00198436e+00],
#        [-1.18471037e+00, -1.18378543e+00, -1.15352388e+00,
#         -1.15140772e+00, -1.14907479e+00, -1.14559185e+00,
#         -1.14933805e+00, -1.14848505e+00, -1.13592735e+00,
#         -1.05867837e+00, -9.38915719e-01],
#        [-9.77087694e-01, -9.78916359e-01, -9.69980489e-01,
#         -9.66930930e-01, -9.61049891e-01, -9.55949315e-01,
#         -9.45990534e-01, -9.34889279e-01, -9.23216131e-01,
#         -8.59329254e-01, -6.79800021e-01],
#        [ 1.30071981e+00,  1.29985984e+00,  1.32450729e+00,
#          1.33100970e+00,  1.32832729e+00,  1.33098857e+00,
#          1.28915266e+00,  1.15293061e+00,  1.15975036e+00,
#          1.05477238e+00,  6.45806827e-01],
#        [ 2.01773209e+00,  2.01779799e+00,  2.05871090e+00,
#          2.06566812e+00,  2.10634251e+00,  2.12603511e+00,
#          2.22141206e+00,  2.35911980e+00,  2.48631701e+00,
#          2.65233148e+00,  2.91963788e+00],
#        [-7.37642723e-02, -6.73045457e-02, -1.17160759e-01,
#         -1.21328242e-01, -1.57108944e-01, -1.71090059e-01,
#         -1.58467832e-01, -1.33150399e-01, -1.77524894e-01,
#         -3.30234023e-01, -7.57549866e-01],
#        [-1.22398291e+00, -1.22837217e+00, -1.20203327e+00,
#         -1.19844597e+00, -1.19786664e+00, -1.19508022e+00,
#         -1.19565421e+00, -1.19319627e+00, -1.17922184e+00,
#         -1.09551271e+00, -9.55216397e-01],
#        [-1.10984537e+00, -1.11415762e+00, -1.08234970e+00,
#         -1.07711430e+00, -1.07151034e+00, -1.06668375e+00,
#         -1.08000639e+00, -1.10377383e+00, -1.10290437e+00,
#         -1.05773305e+00, -9.71335452e-01],
#        [-5.71619282e-01, -5.69129505e-01, -7.12301091e-01,
#         -7.27336805e-01, -7.25337441e-01, -7.33572866e-01,
#         -7.48800908e-01, -7.50281977e-01, -7.67188032e-01,
#         -8.55890697e-01, -9.42094124e-01]])

# %%
pd.DataFrame(stdScResult)
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.559975 -0.549935 -0.539808 -0.539748 -0.552742 -0.557330 -0.548728
# 1   0.733657  0.732909  0.755663  0.753368  0.775762  0.784730  0.788568
# 2   0.242998  0.243107  0.264419  0.265587  0.281987  0.288317  0.342623
# 3  -0.800279 -0.803561 -0.769734 -0.764620 -0.760452 -0.757578 -0.762902
# 4   0.689441  0.690933  0.710371  0.711280  0.734264  0.745837  0.771235
# 5   2.467581  2.461288  2.461828  2.458440  2.452049  2.450601  2.367955
# 6  -1.110340 -1.114440 -1.086432 -1.080756 -1.075289 -1.070528 -1.077978
# 7   0.941884  0.942240  0.947212  0.948420  0.911185  0.893170  0.937879
# 8  -0.009775 -0.010548  0.016159  0.017948  0.026195  0.031452  0.046390
# 9   0.307591  0.319497  0.353786  0.355124  0.346320  0.343016  0.403315
# 10 -0.986315 -0.990112 -0.958284 -0.952645 -0.941649 -0.928549 -0.926175
# 11  0.180107  0.194886  0.152907  0.142631  0.123272  0.111941  0.152838
# 12  0.146162  0.143674  0.170678  0.172588  0.186916  0.194653  0.215896
# 13 -0.249694 -0.251342 -0.219344 -0.211754 -0.205344 -0.199378 -0.201890
# 14  0.813246  0.802429  0.827213  0.835022  0.789955  0.769760  0.625083
# 15  0.299352  0.298870  0.032855  0.001055 -0.002588 -0.026000 -0.099223
# 16 -1.283084 -1.285889 -1.265359 -1.266054 -1.262564 -1.263169 -1.267193
# 17 -1.184710 -1.183785 -1.153524 -1.151408 -1.149075 -1.145592 -1.149338
# 18 -0.977088 -0.978916 -0.969980 -0.966931 -0.961050 -0.955949 -0.945991
# 19  1.300720  1.299860  1.324507  1.331010  1.328327  1.330989  1.289153
# 20  2.017732  2.017798  2.058711  2.065668  2.106343  2.126035  2.221412
# 21 -0.073764 -0.067305 -0.117161 -0.121328 -0.157109 -0.171090 -0.158468
# 22 -1.223983 -1.228372 -1.202033 -1.198446 -1.197867 -1.195080 -1.195654
# 23 -1.109845 -1.114158 -1.082350 -1.077114 -1.071510 -1.066684 -1.080006
# 24 -0.571619 -0.569130 -0.712301 -0.727337 -0.725337 -0.733573 -0.748801
#
#           7         8         9         10
# 0  -0.525514 -0.530150 -0.492087 -0.386751
# 1   0.747599  0.757528  0.791483  0.714211
# 2   0.406557  0.450142  0.541105  0.788578
# 3  -0.760727 -0.755444 -0.721665 -0.785717
# 4   0.804551  0.816178  0.826789  1.014941
# 5   2.268937  2.125744  1.988328  1.432962
# 6  -1.077694 -1.067121 -1.085153 -0.970670
# 7   1.013629  1.031730  1.081406  1.207809
# 8   0.077757  0.140179  0.245285  0.410332
# 9   0.475233  0.562105  0.715571  0.968975
# 10 -0.923783 -0.927391 -0.886944 -0.784097
# 11  0.202900  0.201877  0.157931  0.133720
# 12  0.207770  0.221592  0.275629  0.542736
# 13 -0.226385 -0.236025 -0.397275 -0.763574
# 14  0.507075  0.331036  0.086271 -0.282802
# 15 -0.174193 -0.222361 -0.401546 -0.559202
# 16 -1.271986 -1.259703 -1.174854 -1.001984
# 17 -1.148485 -1.135927 -1.058678 -0.938916
# 18 -0.934889 -0.923216 -0.859329 -0.679800
# 19  1.152931  1.159750  1.054772  0.645807
# 20  2.359120  2.486317  2.652331  2.919638
# 21 -0.133150 -0.177525 -0.330234 -0.757550
# 22 -1.193196 -1.179222 -1.095513 -0.955216
# 23 -1.103774 -1.102904 -1.057733 -0.971335
# 24 -0.750282 -0.767188 -0.855891 -0.942094

# %%
pd.DataFrame(stdScResult).plot(kind='box', rot=90)
# Out:
# <Axes: >

# %%
newNames_sd=[name+'_sd' for name in DatosDepartamentos.iloc[:,3:-1].columns]
newNames_sd
# Out:
# ['Transferencia2023_sd',
#  'Transferencia2022_sd',
#  'Transferencia2021_sd',
#  'Transferencia2020_sd',
#  'Transferencia2019_sd',
#  'Transferencia2018_sd',
#  'Transferencia2017_sd',
#  'Transferencia2016_sd',
#  'Transferencia2015_sd',
#  'Transferencia2014_sd',
#  'Transferencia2013_sd']

# %%
pd.DataFrame(stdScResult,columns=newNames_sd)
# Out:
#     Transferencia2023_sd  Transferencia2022_sd  Transferencia2021_sd  \
# 0              -0.559975             -0.549935             -0.539808
# 1               0.733657              0.732909              0.755663
# 2               0.242998              0.243107              0.264419
# 3              -0.800279             -0.803561             -0.769734
# 4               0.689441              0.690933              0.710371
# 5               2.467581              2.461288              2.461828
# 6              -1.110340             -1.114440             -1.086432
# 7               0.941884              0.942240              0.947212
# 8              -0.009775             -0.010548              0.016159
# 9               0.307591              0.319497              0.353786
# 10             -0.986315             -0.990112             -0.958284
# 11              0.180107              0.194886              0.152907
# 12              0.146162              0.143674              0.170678
# 13             -0.249694             -0.251342             -0.219344
# 14              0.813246              0.802429              0.827213
# 15              0.299352              0.298870              0.032855
# 16             -1.283084             -1.285889             -1.265359
# 17             -1.184710             -1.183785             -1.153524
# 18             -0.977088             -0.978916             -0.969980
# 19              1.300720              1.299860              1.324507
# 20              2.017732              2.017798              2.058711
# 21             -0.073764             -0.067305             -0.117161
# 22             -1.223983             -1.228372             -1.202033
# 23             -1.109845             -1.114158             -1.082350
# 24             -0.571619             -0.569130             -0.712301
#
#     Transferencia2020_sd  Transferencia2019_sd  Transferencia2018_sd  \
# 0              -0.539748             -0.552742             -0.557330
# 1               0.753368              0.775762              0.784730
# 2               0.265587              0.281987              0.288317
# 3              -0.764620             -0.760452             -0.757578
# 4               0.711280              0.734264              0.745837
# 5               2.458440              2.452049              2.450601
# 6              -1.080756             -1.075289             -1.070528
# 7               0.948420              0.911185              0.893170
# 8               0.017948              0.026195              0.031452
# 9               0.355124              0.346320              0.343016
# 10             -0.952645             -0.941649             -0.928549
# 11              0.142631              0.123272              0.111941
# 12              0.172588              0.186916              0.194653
# 13             -0.211754             -0.205344             -0.199378
# 14              0.835022              0.789955              0.769760
# 15              0.001055             -0.002588             -0.026000
# 16             -1.266054             -1.262564             -1.263169
# 17             -1.151408             -1.149075             -1.145592
# 18             -0.966931             -0.961050             -0.955949
# 19              1.331010              1.328327              1.330989
# 20              2.065668              2.106343              2.126035
# 21             -0.121328             -0.157109             -0.171090
# 22             -1.198446             -1.197867             -1.195080
# 23             -1.077114             -1.071510             -1.066684
# 24             -0.727337             -0.725337             -0.733573
#
#     Transferencia2017_sd  Transferencia2016_sd  Transferencia2015_sd  \
# 0              -0.548728             -0.525514             -0.530150
# 1               0.788568              0.747599              0.757528
# 2               0.342623              0.406557              0.450142
# 3              -0.762902             -0.760727             -0.755444
# 4               0.771235              0.804551              0.816178
# 5               2.367955              2.268937              2.125744
# 6              -1.077978             -1.077694             -1.067121
# 7               0.937879              1.013629              1.031730
# 8               0.046390              0.077757              0.140179
# 9               0.403315              0.475233              0.562105
# 10             -0.926175             -0.923783             -0.927391
# 11              0.152838              0.202900              0.201877
# 12              0.215896              0.207770              0.221592
# 13             -0.201890             -0.226385             -0.236025
# 14              0.625083              0.507075              0.331036
# 15             -0.099223             -0.174193             -0.222361
# 16             -1.267193             -1.271986             -1.259703
# 17             -1.149338             -1.148485             -1.135927
# 18             -0.945991             -0.934889             -0.923216
# 19              1.289153              1.152931              1.159750
# 20              2.221412              2.359120              2.486317
# 21             -0.158468             -0.133150             -0.177525
# 22             -1.195654             -1.193196             -1.179222
# 23             -1.080006             -1.103774             -1.102904
# 24             -0.748801             -0.750282             -0.767188
#
#     Transferencia2014_sd  Transferencia2013_sd
# 0              -0.492087             -0.386751
# 1               0.791483              0.714211
# 2               0.541105              0.788578
# 3              -0.721665             -0.785717
# 4               0.826789              1.014941
# 5               1.988328              1.432962
# 6              -1.085153             -0.970670
# 7               1.081406              1.207809
# 8               0.245285              0.410332
# 9               0.715571              0.968975
# 10             -0.886944             -0.784097
# 11              0.157931              0.133720
# 12              0.275629              0.542736
# 13             -0.397275             -0.763574
# 14              0.086271             -0.282802
# 15             -0.401546             -0.559202
# 16             -1.174854             -1.001984
# 17             -1.058678             -0.938916
# 18             -0.859329             -0.679800
# 19              1.054772              0.645807
# 20              2.652331              2.919638
# 21             -0.330234             -0.757550
# 22             -1.095513             -0.955216
# 23             -1.057733             -0.971335
# 24             -0.855891             -0.942094

# %%
# new data frame
stDF=pd.DataFrame(stdScResult,columns=newNames_sd)

# append to the end (right)
DatosDepartamentos=pd.concat([DatosDepartamentos,stDF],axis=1)

# %%
DatosDepartamentos.columns
# Out:
# Index(['Ubigeo', 'Departamento', 'Capital', 'Transferencia2023',
#        'Transferencia2022', 'Transferencia2021', 'Transferencia2020',
#        'Transferencia2019', 'Transferencia2018', 'Transferencia2017',
#        'Transferencia2016', 'Transferencia2015', 'Transferencia2014',
#        'Transferencia2013', 'Trans2023_minMax', 'Transferencia2023_sd',
#        'Transferencia2022_sd', 'Transferencia2021_sd', 'Transferencia2020_sd',
#        'Transferencia2019_sd', 'Transferencia2018_sd', 'Transferencia2017_sd',
#        'Transferencia2016_sd', 'Transferencia2015_sd', 'Transferencia2014_sd',
#        'Transferencia2013_sd'],
#       dtype='object')

# %%
DatosDepartamentos.iloc[:,3:].plot(kind='box', rot=90);

# %%
PeruDepartamentos.to_csv(os.path.join("Datos_por_zona","DatosRegionales", "PeruDepartamentos.csv"))

# %%
PeruDepartamentos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 80 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    25 non-null     float64
#  1   CCDD        25 non-null     object
#  2   NOMBDEP     25 non-null     object
#  3   FUENTE      25 non-null     object
#  4   FUENTE_1    0 non-null      float64
#  5   POB_PROYEC  25 non-null     float64
#  6   POBTOTAL    25 non-null     float64
#  7   POB_EDAD_T  25 non-null     float64
#  8   POB_EDAD_1  25 non-null     float64
#  9   POB_EDAD_E  25 non-null     float64
#  10  POB_EDAD_2  25 non-null     float64
#  11  DENSIDAD    25 non-null     float64
#  12  POBMASCU    25 non-null     float64
#  13  POBFEMEN    25 non-null     float64
#  14  POBMASCU_P  25 non-null     float64
#  15  POBFEMEN_P  25 non-null     float64
#  16  R_MASCULIN  25 non-null     float64
#  17  POBURBANA   25 non-null     float64
#  18  POBRURAL    25 non-null     float64
#  19  POBURBANA_  25 non-null     float64
#  20  POBRURAL_P  25 non-null     float64
#  21  EDAD_PROME  25 non-null     float64
#  22  EDAD_MEDIA  25 non-null     float64
#  23  POB_0_14    25 non-null     float64
#  24  POB_0_14_P  25 non-null     float64
#  25  POB_15_29   25 non-null     float64
#  26  POB_15_29_  25 non-null     float64
#  27  POB_30_59   25 non-null     float64
#  28  POB_30_59_  25 non-null     float64
#  29  POB_60_MAS  25 non-null     float64
#  30  POB_60_M_1  25 non-null     float64
#  31  POB_ANALFA  25 non-null     float64
#  32  POB_ANAL_1  25 non-null     float64
#  33  HOMBRES_AN  25 non-null     float64
#  34  HOMBRES__1  25 non-null     float64
#  35  MUJERES_AN  25 non-null     float64
#  36  MUJERES__1  25 non-null     float64
#  37  MUJERES_ED  25 non-null     float64
#  38  MUJERES__2  25 non-null     float64
#  39  TOTAL_MADR  25 non-null     float64
#  40  MADRES_SOL  25 non-null     float64
#  41  MADRES_S_1  25 non-null     float64
#  42  MUJERES_AD  25 non-null     float64
#  43  MADRES_ADO  25 non-null     float64
#  44  MADRES_A_1  25 non-null     float64
#  45  AL_MENOS_1  25 non-null     float64
#  46  AL_MENOS_2  25 non-null     float64
#  47  SIN_DISCAP  25 non-null     float64
#  48  SIN_DISC_1  25 non-null     float64
#  49  ALGUNA_NBI  25 non-null     float64
#  50  NBI_PORC    25 non-null     float64
#  51  VIV_PARTIC  25 non-null     float64
#  52  VIV_PART_1  25 non-null     float64
#  53  VIV_PART_2  25 non-null     float64
#  54  HOGARES     25 non-null     float64
#  55  Shape_Leng  25 non-null     float64
#  56  Shape_Area  25 non-null     float64
#  57  IC_INF      25 non-null     float64
#  58  IC_SUP      25 non-null     float64
#  59  UBIC_POBMO  25 non-null     float64
#  60  TOTAL_DEFU  25 non-null     float64
#  61  TOTAL_DE_1  25 non-null     float64
#  62  TOTAL_DE_2  25 non-null     float64
#  63  NAC_BAJOPE  25 non-null     float64
#  64  NAC_BAJO_1  25 non-null     float64
#  65  MUJERES_NA  25 non-null     float64
#  66  MUJERES__3  25 non-null     float64
#  67  HOMBRES_NA  25 non-null     float64
#  68  HOMBRES__2  25 non-null     float64
#  69  TOTAL_NACI  25 non-null     float64
#  70  IND_121951  25 non-null     float64
#  71  IND_122042  25 non-null     float64
#  72  IND_122047  25 non-null     float64
#  73  IND_516462  25 non-null     float64
#  74  IND_516484  25 non-null     float64
#  75  Shape_Le_1  25 non-null     float64
#  76  Shape_Ar_1  25 non-null     float64
#  77  Shape_Le_2  25 non-null     float64
#  78  Shape_Ar_2  25 non-null     float64
#  79  geometry    25 non-null     geometry
# dtypes: float64(76), geometry(1), object(3)
# memory usage: 15.8+ KB

# %%
DatosDepartamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ubigeo                25 non-null     int64
#  1   Departamento          25 non-null     object
#  2   Capital               25 non-null     object
#  3   Transferencia2023     25 non-null     int64
#  4   Transferencia2022     25 non-null     int64
#  5   Transferencia2021     25 non-null     int64
#  6   Transferencia2020     25 non-null     int64
#  7   Transferencia2019     25 non-null     int64
#  8   Transferencia2018     25 non-null     int64
#  9   Transferencia2017     25 non-null     int64
#  10  Transferencia2016     25 non-null     int64
#  11  Transferencia2015     25 non-null     int64
#  12  Transferencia2014     25 non-null     float64
#  13  Transferencia2013     25 non-null     float64
#  14  Trans2023_minMax      25 non-null     float64
#  15  Transferencia2023_sd  25 non-null     float64
#  16  Transferencia2022_sd  25 non-null     float64
#  17  Transferencia2021_sd  25 non-null     float64
#  18  Transferencia2020_sd  25 non-null     float64
#  19  Transferencia2019_sd  25 non-null     float64
#  20  Transferencia2018_sd  25 non-null     float64
#  21  Transferencia2017_sd  25 non-null     float64
#  22  Transferencia2016_sd  25 non-null     float64
#  23  Transferencia2015_sd  25 non-null     float64
#  24  Transferencia2014_sd  25 non-null     float64
#  25  Transferencia2013_sd  25 non-null     float64
# dtypes: float64(14), int64(10), object(2)
# memory usage: 5.2+ KB

# %%
convert_dict = {'Transferencia2023': float,
                'Transferencia2022': float,
                'Transferencia2021': float,
                'Transferencia2020': float,
                'Transferencia2019': float,
                'Transferencia2018': float,
                'Transferencia2017': float,
                'Transferencia2016': float,
                'Transferencia2015': float
                }
 
DatosDepartamentos = DatosDepartamentos.astype(convert_dict)
print(DatosDepartamentos.dtypes)
# Out:
# Ubigeo                    int64
# Departamento             object
# Capital                  object
# Transferencia2023       float64
# Transferencia2022       float64
# Transferencia2021       float64
# Transferencia2020       float64
# Transferencia2019       float64
# Transferencia2018       float64
# Transferencia2017       float64
# Transferencia2016       float64
# Transferencia2015       float64
# Transferencia2014       float64
# Transferencia2013       float64
# Trans2023_minMax        float64
# Transferencia2023_sd    float64
# Transferencia2022_sd    float64
# Transferencia2021_sd    float64
# Transferencia2020_sd    float64
# Transferencia2019_sd    float64
# Transferencia2018_sd    float64
# Transferencia2017_sd    float64
# Transferencia2016_sd    float64
# Transferencia2015_sd    float64
# Transferencia2014_sd    float64
# Transferencia2013_sd    float64
# dtype: object

# %%
PeruDepartamentos.shape,DatosDepartamentos.shape
# Out:
# ((25, 80), (25, 26))

# %%
PeruDepartamentos.rename(columns = {'NOMBDEP':'Departamento'}, inplace = True)

# %%
PeruDepartamentos.head()
# Out:
#    OBJECTID CCDD Departamento                 FUENTE  FUENTE_1  POB_PROYEC  \
# 0       1.0   01     AMAZONAS  INEI - CPV RESULTADOS       NaN    426806.0
# 1       2.0   02       ANCASH  INEI - CPV RESULTADOS       NaN   1180638.0
# 2       3.0   03     APURIMAC  INEI - CPV RESULTADOS       NaN    430736.0
# 3       4.0   04     AREQUIPA  INEI - CPV RESULTADOS       NaN   1497438.0
# 4       5.0   05     AYACUCHO  INEI - CPV RESULTADOS       NaN    668213.0
#
#     POBTOTAL  POB_EDAD_T  POB_EDAD_1  POB_EDAD_E  ...  IND_121951  \
# 0   417365.0    289648.0        69.4    239212.0  ...      2139.0
# 1  1139115.0    850842.0        74.7    701614.0  ...      9366.0
# 2   424259.0    310196.0        73.1    252356.0  ...      3723.0
# 3  1460433.0   1135965.0        77.8    970511.0  ...     10670.0
# 4   650940.0    478429.0        73.5    390780.0  ...      4699.0
#
#      IND_122042    IND_122047   IND_516462  IND_516484  Shape_Le_1  \
# 0  3.184694e+05  3.745422e+05   5094318.10     34164.0    0.022988
# 1  2.252303e+06  1.363318e+06  34431748.77     74385.0    0.000000
# 2  7.025553e+05  6.626253e+05   8673503.09     48594.0    0.000000
# 3  2.094167e+06  1.296536e+06  64872968.90     48033.0    0.000000
# 4  9.729801e+05  9.490687e+05  14610956.27     58941.0    0.000000
#
#    Shape_Ar_1  Shape_Le_2  Shape_Ar_2  \
# 0    0.000013   12.894071    3.203362
# 1    0.000000   11.640227    2.954639
# 2    0.000000    7.730082    1.765933
# 3    0.000000   17.391102    5.330046
# 4    0.000000   17.132543    3.643617
#
#                                             geometry
# 0  POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 1  POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...
# 2  POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4  POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
#
# [5 rows x 80 columns]

# %%
PeruMapaOficial = DatosDepartamentos.merge(PeruDepartamentos,
                                           how='inner',left_on='Departamento',right_on='Departamento')

# %%
PeruMapaOficial.head()
# Out:
#    Ubigeo Departamento      Capital  Transferencia2023  Transferencia2022  \
# 0       1     AMAZONAS  Chachapoyas         14922000.0         21421250.0
# 1       2       ANCASH       Huaraz         38474000.0         54336250.0
# 2       3     APURIMAC      Abancay         29541000.0         41769000.0
# 3       4     AREQUIPA     Arequipa         10547000.0         14913750.0
# 4       5     AYACUCHO     Ayacucho         37669000.0         53259250.0
#
#    Transferencia2021  Transferencia2020  Transferencia2019  Transferencia2018  \
# 0         26711750.0         23282750.0         19145500.0         18791000.0
# 1         69794500.0         61096250.0         51928000.0         51692750.0
# 2         53457500.0         46832500.0         39743500.0         39522750.0
# 3         19065250.0         16707000.0         14020000.0         13881750.0
# 4         68288250.0         59865500.0         50904000.0         50739250.0
#
#    Transferencia2017  ...  IND_121951    IND_122042    IND_122047  \
# 0         18377250.0  ...      2139.0  3.184694e+05  3.745422e+05
# 1         50029500.0  ...      9366.0  2.252303e+06  1.363318e+06
# 2         39474500.0  ...      3723.0  7.025553e+05  6.626253e+05
# 3         13308000.0  ...     10670.0  2.094167e+06  1.296536e+06
# 4         49619250.0  ...      4699.0  9.729801e+05  9.490687e+05
#
#     IND_516462  IND_516484  Shape_Le_1  Shape_Ar_1  Shape_Le_2  Shape_Ar_2  \
# 0   5094318.10     34164.0    0.022988    0.000013   12.894071    3.203362
# 1  34431748.77     74385.0    0.000000    0.000000   11.640227    2.954639
# 2   8673503.09     48594.0    0.000000    0.000000    7.730082    1.765933
# 3  64872968.90     48033.0    0.000000    0.000000   17.391102    5.330046
# 4  14610956.27     58941.0    0.000000    0.000000   17.132543    3.643617
#
#                                             geometry
# 0  POLYGON ((-77.81211 -2.98962, -77.81332 -2.990...
# 1  POLYGON ((-77.64692 -8.05086, -77.64669 -8.052...
# 2  POLYGON ((-73.74632 -13.17456, -73.74570 -13.1...
# 3  POLYGON ((-71.98109 -14.64062, -71.98093 -14.6...
# 4  POLYGON ((-74.34843 -12.17503, -74.35000 -12.1...
#
# [5 rows x 105 columns]

# %%
PeruMapaOficial = PeruDepartamentos.merge(DatosDepartamentos,
                                           how='inner',left_on='Departamento',right_on='Departamento')

# %%
PeruMapaOficial
# Out:
#     OBJECTID CCDD   Departamento                 FUENTE  FUENTE_1  POB_PROYEC  \
# 0        1.0   01       AMAZONAS  INEI - CPV RESULTADOS       NaN    426806.0
# 1        2.0   02         ANCASH  INEI - CPV RESULTADOS       NaN   1180638.0
# 2        3.0   03       APURIMAC  INEI - CPV RESULTADOS       NaN    430736.0
# 3        4.0   04       AREQUIPA  INEI - CPV RESULTADOS       NaN   1497438.0
# 4        5.0   05       AYACUCHO  INEI - CPV RESULTADOS       NaN    668213.0
# 5        6.0   06      CAJAMARCA  INEI - CPV RESULTADOS       NaN   1453711.0
# 6        7.0   07         CALLAO  INEI - CPV RESULTADOS       NaN   1129854.0
# 7        8.0   08          CUSCO  INEI - CPV RESULTADOS       NaN   1357075.0
# 8        9.0   09   HUANCAVELICA  INEI - CPV RESULTADOS       NaN    365317.0
# 9       10.0   10        HUANUCO  INEI - CPV RESULTADOS       NaN    760267.0
# 10      11.0   11            ICA  INEI - CPV RESULTADOS       NaN    975182.0
# 11      12.0   12          JUNIN  INEI - CPV RESULTADOS       NaN   1361467.0
# 12      13.0   13    LA LIBERTAD  INEI - CPV RESULTADOS       NaN   2016771.0
# 13      14.0   14     LAMBAYEQUE  INEI - CPV RESULTADOS       NaN   1310785.0
# 14      15.0   15           LIMA  INEI - CPV RESULTADOS       NaN  10628470.0
# 15      16.0   16         LORETO  INEI - CPV RESULTADOS       NaN   1027559.0
# 16      17.0   17  MADRE DE DIOS  INEI - CPV RESULTADOS       NaN    173811.0
# 17      18.0   18       MOQUEGUA  INEI - CPV RESULTADOS       NaN    192740.0
# 18      19.0   19          PASCO  INEI - CPV RESULTADOS       NaN    271904.0
# 19      20.0   20          PIURA  INEI - CPV RESULTADOS       NaN   2047954.0
# 20      21.0   21           PUNO  INEI - CPV RESULTADOS       NaN   1237997.0
# 21      22.0   22     SAN MARTIN  INEI - CPV RESULTADOS       NaN    899648.0
# 22      23.0   23          TACNA  INEI - CPV RESULTADOS       NaN    370974.0
# 23      24.0   24         TUMBES  INEI - CPV RESULTADOS       NaN    251521.0
# 24      25.0   25        UCAYALI  INEI - CPV RESULTADOS       NaN    589110.0
#
#       POBTOTAL  POB_EDAD_T  POB_EDAD_1  POB_EDAD_E  ...  Transferencia2022_sd  \
# 0     417365.0    289648.0        69.4    239212.0  ...             -0.549935
# 1    1139115.0    850842.0        74.7    701614.0  ...              0.732909
# 2     424259.0    310196.0        73.1    252356.0  ...              0.243107
# 3    1460433.0   1135965.0        77.8    970511.0  ...             -0.803561
# 4     650940.0    478429.0        73.5    390780.0  ...              0.690933
# 5    1427527.0   1032364.0        72.3    849911.0  ...              2.461288
# 6    1046953.0    806753.0        77.1    691439.0  ...             -1.114440
# 7    1315220.0    983239.0        74.8    819761.0  ...              0.942240
# 8     367252.0    264458.0        72.0    209924.0  ...             -0.010548
# 9     759962.0    545990.0        71.8    452246.0  ...              0.319497
# 10    893292.0    663648.0        74.3    565008.0  ...             -0.990112
# 11   1316894.0    970597.0        73.7    810252.0  ...              0.194886
# 12   1888972.0   1392785.0        73.7   1169761.0  ...              0.143674
# 13   1244821.0    925948.0        74.4    775945.0  ...             -0.251342
# 14  10135009.0   8001470.0        78.9   6874069.0  ...              0.802429
# 15    981897.0    640208.0        65.2    532563.0  ...              0.298870
# 16    161204.0    113819.0        70.6    101418.0  ...             -1.285889
# 17    182017.0    142374.0        78.2    121568.0  ...             -1.183785
# 18    272136.0    199207.0        73.2    170544.0  ...             -0.978916
# 19   1929970.0   1386207.0        71.8   1162381.0  ...              1.299860
# 20   1226936.0    942507.0        76.8    783408.0  ...              2.017798
# 21    862459.0    606995.0        70.4    515670.0  ...             -0.067305
# 22    349056.0    273501.0        78.4    237450.0  ...             -1.228372
# 23    234698.0    169803.0        72.3    145828.0  ...             -1.114158
# 24    548998.0    368684.0        67.2    315367.0  ...             -0.569130
#
#     Transferencia2021_sd  Transferencia2020_sd  Transferencia2019_sd  \
# 0              -0.539808             -0.539748             -0.552742
# 1               0.755663              0.753368              0.775762
# 2               0.264419              0.265587              0.281987
# 3              -0.769734             -0.764620             -0.760452
# 4               0.710371              0.711280              0.734264
# 5               2.461828              2.458440              2.452049
# 6              -1.086432             -1.080756             -1.075289
# 7               0.947212              0.948420              0.911185
# 8               0.016159              0.017948              0.026195
# 9               0.353786              0.355124              0.346320
# 10             -0.958284             -0.952645             -0.941649
# 11              0.152907              0.142631              0.123272
# 12              0.170678              0.172588              0.186916
# 13             -0.219344             -0.211754             -0.205344
# 14              0.827213              0.835022              0.789955
# 15              0.032855              0.001055             -0.002588
# 16             -1.265359             -1.266054             -1.262564
# 17             -1.153524             -1.151408             -1.149075
# 18             -0.969980             -0.966931             -0.961050
# 19              1.324507              1.331010              1.328327
# 20              2.058711              2.065668              2.106343
# 21             -0.117161             -0.121328             -0.157109
# 22             -1.202033             -1.198446             -1.197867
# 23             -1.082350             -1.077114             -1.071510
# 24             -0.712301             -0.727337             -0.725337
#
#     Transferencia2018_sd  Transferencia2017_sd  Transferencia2016_sd  \
# 0              -0.557330             -0.548728             -0.525514
# 1               0.784730              0.788568              0.747599
# 2               0.288317              0.342623              0.406557
# 3              -0.757578             -0.762902             -0.760727
# 4               0.745837              0.771235              0.804551
# 5               2.450601              2.367955              2.268937
# 6              -1.070528             -1.077978             -1.077694
# 7               0.893170              0.937879              1.013629
# 8               0.031452              0.046390              0.077757
# 9               0.343016              0.403315              0.475233
# 10             -0.928549             -0.926175             -0.923783
# 11              0.111941              0.152838              0.202900
# 12              0.194653              0.215896              0.207770
# 13             -0.199378             -0.201890             -0.226385
# 14              0.769760              0.625083              0.507075
# 15             -0.026000             -0.099223             -0.174193
# 16             -1.263169             -1.267193             -1.271986
# 17             -1.145592             -1.149338             -1.148485
# 18             -0.955949             -0.945991             -0.934889
# 19              1.330989              1.289153              1.152931
# 20              2.126035              2.221412              2.359120
# 21             -0.171090             -0.158468             -0.133150
# 22             -1.195080             -1.195654             -1.193196
# 23             -1.066684             -1.080006             -1.103774
# 24             -0.733573             -0.748801             -0.750282
#
#     Transferencia2015_sd  Transferencia2014_sd  Transferencia2013_sd
# 0              -0.530150             -0.492087             -0.386751
# 1               0.757528              0.791483              0.714211
# 2               0.450142              0.541105              0.788578
# 3              -0.755444             -0.721665             -0.785717
# 4               0.816178              0.826789              1.014941
# 5               2.125744              1.988328              1.432962
# 6              -1.067121             -1.085153             -0.970670
# 7               1.031730              1.081406              1.207809
# 8               0.140179              0.245285              0.410332
# 9               0.562105              0.715571              0.968975
# 10             -0.927391             -0.886944             -0.784097
# 11              0.201877              0.157931              0.133720
# 12              0.221592              0.275629              0.542736
# 13             -0.236025             -0.397275             -0.763574
# 14              0.331036              0.086271             -0.282802
# 15             -0.222361             -0.401546             -0.559202
# 16             -1.259703             -1.174854             -1.001984
# 17             -1.135927             -1.058678             -0.938916
# 18             -0.923216             -0.859329             -0.679800
# 19              1.159750              1.054772              0.645807
# 20              2.486317              2.652331              2.919638
# 21             -0.177525             -0.330234             -0.757550
# 22             -1.179222             -1.095513             -0.955216
# 23             -1.102904             -1.057733             -0.971335
# 24             -0.767188             -0.855891             -0.942094
#
# [25 rows x 105 columns]

# %%
print(PeruMapaOficial.columns)
# Out:
# Index(['OBJECTID', 'CCDD', 'Departamento', 'FUENTE', 'FUENTE_1', 'POB_PROYEC',
#        'POBTOTAL', 'POB_EDAD_T', 'POB_EDAD_1', 'POB_EDAD_E',
#        ...
#        'Transferencia2022_sd', 'Transferencia2021_sd', 'Transferencia2020_sd',
#        'Transferencia2019_sd', 'Transferencia2018_sd', 'Transferencia2017_sd',
#        'Transferencia2016_sd', 'Transferencia2015_sd', 'Transferencia2014_sd',
#        'Transferencia2013_sd'],
#       dtype='object', length=105)

# %%
PeruMapaOficial['Trans2023_minMax'].describe()
# Out:
# count    25.000000
# mean      3.420950
# std       2.721173
# min       0.000000
# 25%       0.815845
# 50%       3.394889
# 75%       5.259135
# max      10.000000
# Name: Trans2023_minMax, dtype: float64

# %%
PeruMapaOficial.Trans2023_minMax.hist()
# Out:
# <Axes: >

# %%
PeruMapaOficial.boxplot(column=['Trans2023_minMax'])
# Out:
# <Axes: >

# %%
import mapclassify 
import numpy as np

np.random.seed(12345) # so we all get the same results!

# let's try 5 intervals
K=5
theVar=PeruMapaOficial.Trans2023_minMax
# same interval width, easy interpretation
ei5 = mapclassify.EqualInterval(theVar, k=K)
# same interval width based on standard deviation, easy - but not as the previous one, poor when high skewness
msd = mapclassify.StdMean(theVar)
# interval width varies, counts per interval are close, not easy to grasp, repeated values complicate cuts                                
q5=mapclassify.Quantiles(theVar,k=K)

# based on similarity, good for multimodal data 
mb5 = mapclassify.MaximumBreaks(theVar, k=K)
# based on similarity, good for skewed data
ht = mapclassify.HeadTailBreaks(theVar) # no K needed
# based on similarity, optimizer
fj5 = mapclassify.FisherJenks(theVar, k=K)
# based on similarity, optimizer
jc5 = mapclassify.JenksCaspall(theVar, k=K)
# based on similarity, optimizer
mp5 = mapclassify.MaxP(theVar, k=K)

# %%
ht
# Out:
# HeadTailBreaks
#
#    Interval      Count
# ----------------------
# [ 0.00,  3.42] |    13
# ( 3.42,  5.67] |     8
# ( 5.67,  7.91] |     2
# ( 7.91,  9.40] |     1
# ( 9.40, 10.00] |     1

# %%
ht.yb
# Out:
# array([0, 1, 1, 0, 1, 4, 0, 2, 0, 1, 0, 1, 1, 0, 1, 1, 0, 0, 0, 2, 3, 0,
#        0, 0, 0])

# %%
np.unique(ht.yb,return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([13,  8,  2,  1,  1], dtype=int64))

# %%
pd.Series(ht.yb).value_counts()
# Out:
# 0    13
# 1     8
# 2     2
# 4     1
# 3     1
# Name: count, dtype: int64

# %%
ht.bins
# Out:
# array([ 3.42095043,  5.67398892,  7.90543311,  9.40030753, 10.        ])

# %%
HT_bins=list(ht.bins)
HT_bins.insert(0,theVar.min())

# %%
PeruMapaOficial.Trans2023_minMax.hist(bins=HT_bins)
# Out:
# <Axes: >

# %%
class5 = q5, ei5,msd, ht, mb5, fj5, jc5, mp5
# Collect ADCM for each classifier
fits = np.array([ c.adcm for c in class5])
# Convert ADCM scores to a DataFrame
adcms = pd.DataFrame(fits)
# Add classifier names
adcms['classifier'] = [c.name for c in class5]
# Add column names to the ADCM
adcms.columns = ['ADCM', 'Classifier']

# %%
adcms.sort_values('ADCM').plot.barh(x='Classifier')
# Out:
# <Axes: ylabel='Classifier'>

# %%
PeruMapaOficial['Total_ei5'] = ei5.yb
PeruMapaOficial['Total_fj5'] = fj5.yb
PeruMapaOficial['Total_jc5'] = jc5.yb

# we have:
PeruMapaOficial[['Total_ei5','Total_fj5','Total_jc5']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Total_ei5  25 non-null     int32
#  1   Total_fj5  25 non-null     int32
#  2   Total_jc5  25 non-null     int32
# dtypes: int32(3)
# memory usage: 428.0 bytes

# %%
class5new = ei5,fj5, jc5
pd.DataFrame(
    {c.name: c.counts for c in class5new},
    index=['Class-{}'.format(i) for i in range(5)]
)
# Out:
#          EqualInterval  FisherJenks  JenksCaspall
# Class-0             10            7             5
# Class-1              5            4             5
# Class-2              7            7             3
# Class-3              1            5             7
# Class-4              2            2             5

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, figsize=(10, 10))
PeruMapaOficial.plot(column='Total_fj5', 
        cmap='viridis', 
        categorical=True,
        edgecolor='white', 
        linewidth=0., 
        alpha=0.75, 
        legend=True,
        legend_kwds={'loc':3},
        ax=ax
       )

ax.set_axis_off()
# Out:
# C:\Users\MEMO 123\anaconda3\envs\ASIE\lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):

# %%
# learn "enumerate()":
varsToPlot = ['Total_ei5','Total_fj5','Total_jc5']
[x for x in enumerate(varsToPlot)]
# Out:
# [(0, 'Total_ei5'), (1, 'Total_fj5'), (2, 'Total_jc5')]

# %%
# create 3 figures
f, axs = plt.subplots(nrows=3, ncols=1, figsize=(12, 12))

axs = axs.flatten() # just a one dimensional index

for i, col in enumerate(varsToPlot):    
    HERE = axs[i]# select the axis where the map will go
    PeruMapaOficial.plot(column=col, categorical=True, linewidth=0.1,
                legend=True,cmap='hot_r',edgecolor='grey',
                legend_kwds={'loc':3},
                ax=HERE)
    # Remove axis clutter
    ax.set_axis_off()
    # Set the axis title to the name of variable being plotted
    ax.set_title(col)
# Display the figure
plt.show()
# Out:
# C:\Users\MEMO 123\anaconda3\envs\ASIE\lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# C:\Users\MEMO 123\anaconda3\envs\ASIE\lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# C:\Users\MEMO 123\anaconda3\envs\ASIE\lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):

# %%
PeruMapaOficial.to_file(os.path.join("PeruMapaColoreado2023.gpkg"), layer='Departamentos', driver="GPKG")

# %%
# facetting
f, axs = plt.subplots(nrows=2, ncols=3, figsize=(8, 8))
axs = axs.flatten()

for i in range(5):  
    ax = axs[i]# select the axis where the map will go
    PeruMapaOficial.plot(ax=ax,color='gainsboro')
    PeruMapaOficial[PeruMapaOficial.Total_fj5==i].plot(ax=ax,color='red')
    ax.set_axis_off()
    ax.set_title("level_"+str(i))
f.delaxes(axs[5]) # bye empty subplot
plt.show()
